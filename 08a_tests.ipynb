# %%
import multiModel as mm
from multiModel import MultiInputModel
from glob import glob
import os
import matplotlib.pyplot as plt
import numpy as np

# Załaduj dane
test_dataset = mm.MultiInputDataset("CSV/dataset/test_224.csv", transform_rgb=mm.transform_rgb, transform_binary=mm.transform_binary)
test_loader = mm.DataLoader(test_dataset, batch_size=32, shuffle=False)
path_results = "training_results_224_2"
for path_model in glob(f"{path_results}/*.pth"):
    print(f"Testowanie modelu: {path_model}")
    # Wywołanie funkcji testującej
    cm, y_true, y_pred = mm.test_model(
        path_model=path_model,
        test_loader=test_loader,
        device="cuda"
    )

    # Wyświetlenie macierzy pomyłek
    class_names = list(test_dataset.class_to_idx.keys())
    plt.figure(figsize=(10, 8))
    mm.sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Przewidywane klasy")
    plt.ylabel("Rzeczywiste klasy")
    plt.title(f"Macierz pomyłek: {os.path.split(os.path.basename(path_model))[0]}")
    plt.savefig(os.path.splitext(path_model)[0] + ".png", dpi=300, bbox_inches="tight")
    plt.show()

    # Inne metryki


    # Otwórz plik w trybie zapisu
    with open(os.path.splitext(path_model)[0] + ".txt", "w") as file:
        # Zapisz dokładność
        accuracy = mm.accuracy_score(y_true, y_pred)
        file.write(f"Dokładność: {accuracy:.4f}\n")
        
        # Zapisz raport klasyfikacji
        classification_report = mm.classification_report(y_true, y_pred, target_names=class_names)
        file.write("\nRaport klasyfikacji:\n")
        file.write(classification_report + "\n")
        
        # Zapisz informacje o największej liczbie pomyłek
        off_diagonal = cm - np.diag(np.diag(cm))  # Macierz bez przekątnej
        max_misclassified = np.unravel_index(np.argmax(off_diagonal), off_diagonal.shape)
        
        most_confused_classes = f"Najczęściej mylone klasy: {class_names[max_misclassified[0]]} → {class_names[max_misclassified[1]]}"
        misclassified_count = f"Liczba pomyłek: {off_diagonal[max_misclassified]}"
        
        file.write("\n" + most_confused_classes + "\n")
        file.write(misclassified_count + "\n")
        file.close()

    # Wyświetl w konsoli również, jeśli chcesz
    print(f"Dokładność: {accuracy:.4f}")
    print("\nRaport klasyfikacji:")
    print(classification_report)
    print(most_confused_classes)
    print(misclassified_count)
# Out:
# Testowanie modelu: training_results_224_2/best_model_efficientnet_b0.pth
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# Dokładność: 0.9819
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.98      0.98      0.98      1430
#                                  ella       0.98      0.97      0.98      1342
#                        jary_hajduczek       0.99      0.94      0.96      1339
# jary_jeczmien_skald_czyszczony_insect       0.99      0.99      0.99      1368
#                jary_oberek_czyszczony       0.97      0.99      0.98      1321
#                  jary_skarb_czyzczony       0.98      0.99      0.98      1385
#                          kucyk_insect       1.00      1.00      1.00      1165
#                            kws_atrika       0.98      0.99      0.98      1361
#                              kws_olof       0.98      1.00      0.99      1419
#                          nagradowicki       0.98      0.98      0.98      1287
#                               penguin       0.98      0.98      0.98      1467
#
#                              accuracy                           0.98     14884
#                             macro avg       0.98      0.98      0.98     14884
#                          weighted avg       0.98      0.98      0.98     14884
#
# Najczęściej mylone klasy: jary_hajduczek → jary_oberek_czyszczony
# Liczba pomyłek: 29
# Testowanie modelu: training_results_224_2/best_model_efficientnet_v2_m.pth
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# Dokładność: 0.9764
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.99      0.97      0.98      1430
#                                  ella       0.97      0.97      0.97      1342
#                        jary_hajduczek       0.96      0.93      0.95      1339
# jary_jeczmien_skald_czyszczony_insect       0.99      0.98      0.99      1368
#                jary_oberek_czyszczony       0.94      0.99      0.97      1321
#                  jary_skarb_czyzczony       0.98      0.98      0.98      1385
#                          kucyk_insect       1.00      1.00      1.00      1165
#                            kws_atrika       0.97      0.98      0.98      1361
#                              kws_olof       0.98      0.99      0.99      1419
#                          nagradowicki       0.98      0.97      0.98      1287
#                               penguin       0.98      0.97      0.97      1467
#
#                              accuracy                           0.98     14884
#                             macro avg       0.98      0.98      0.98     14884
#                          weighted avg       0.98      0.98      0.98     14884
#
# Najczęściej mylone klasy: jary_hajduczek → jary_oberek_czyszczony
# Liczba pomyłek: 30
# Testowanie modelu: training_results_224_2/best_model_mobilenet_v3_small.pth
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# Dokładność: 0.9683
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.94      0.99      0.96      1430
#                                  ella       0.97      0.94      0.96      1342
#                        jary_hajduczek       0.94      0.96      0.95      1339
# jary_jeczmien_skald_czyszczony_insect       0.98      0.98      0.98      1368
#                jary_oberek_czyszczony       0.97      0.99      0.98      1321
#                  jary_skarb_czyzczony       0.99      0.94      0.97      1385
#                          kucyk_insect       1.00      0.99      0.99      1165
#                            kws_atrika       0.98      0.94      0.96      1361
#                              kws_olof       0.99      0.98      0.99      1419
#                          nagradowicki       0.96      0.96      0.96      1287
#                               penguin       0.95      0.97      0.96      1467
#
#                              accuracy                           0.97     14884
#                             macro avg       0.97      0.97      0.97     14884
#                          weighted avg       0.97      0.97      0.97     14884
#
# Najczęściej mylone klasy: ella → penguin
# Liczba pomyłek: 38
# Testowanie modelu: training_results_224_2/best_model_resnet34.pth
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# Dokładność: 0.9673
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.96      0.97      0.96      1430
#                                  ella       0.95      0.97      0.96      1342
#                        jary_hajduczek       0.94      0.94      0.94      1339
# jary_jeczmien_skald_czyszczony_insect       0.98      0.97      0.97      1368
#                jary_oberek_czyszczony       0.97      0.97      0.97      1321
#                  jary_skarb_czyzczony       0.98      0.98      0.98      1385
#                          kucyk_insect       1.00      0.99      0.99      1165
#                            kws_atrika       0.97      0.97      0.97      1361
#                              kws_olof       0.97      0.98      0.98      1419
#                          nagradowicki       0.96      0.97      0.96      1287
#                               penguin       0.98      0.95      0.96      1467
#
#                              accuracy                           0.97     14884
#                             macro avg       0.97      0.97      0.97     14884
#                          weighted avg       0.97      0.97      0.97     14884
#
# Najczęściej mylone klasy: penguin → ella
# Liczba pomyłek: 36
# Testowanie modelu: training_results_224_2/best_model_swin_t.pth
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /media/3TB/github/Multi-input-Grain-CNN/multiModel.py:395: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(path_model, map_location=device)
# Dokładność: 0.0986
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.00      0.00      0.00      1430
#                                  ella       0.00      0.00      0.00      1342
#                        jary_hajduczek       0.00      0.00      0.00      1339
# jary_jeczmien_skald_czyszczony_insect       0.00      0.00      0.00      1368
#                jary_oberek_czyszczony       0.00      0.00      0.00      1321
#                  jary_skarb_czyzczony       0.00      0.00      0.00      1385
#                          kucyk_insect       0.00      0.00      0.00      1165
#                            kws_atrika       0.00      0.00      0.00      1361
#                              kws_olof       0.00      0.00      0.00      1419
#                          nagradowicki       0.00      0.00      0.00      1287
#                               penguin       0.10      1.00      0.18      1467
#
#                              accuracy                           0.10     14884
#                             macro avg       0.01      0.09      0.02     14884
#                          weighted avg       0.01      0.10      0.02     14884
#
# Najczęściej mylone klasy: basil → penguin
# Liczba pomyłek: 1430
# Testowanie modelu: training_results_224_2/best_model_vit_b_16.pth
# Dokładność: 0.0986
#
# Raport klasyfikacji:
#                                        precision    recall  f1-score   support
#
#                                 basil       0.00      0.00      0.00      1430
#                                  ella       0.00      0.00      0.00      1342
#                        jary_hajduczek       0.00      0.00      0.00      1339
# jary_jeczmien_skald_czyszczony_insect       0.00      0.00      0.00      1368
#                jary_oberek_czyszczony       0.00      0.00      0.00      1321
#                  jary_skarb_czyzczony       0.00      0.00      0.00      1385
#                          kucyk_insect       0.00      0.00      0.00      1165
#                            kws_atrika       0.00      0.00      0.00      1361
#                              kws_olof       0.00      0.00      0.00      1419
#                          nagradowicki       0.00      0.00      0.00      1287
#                               penguin       0.10      1.00      0.18      1467
#
#                              accuracy                           0.10     14884
#                             macro avg       0.01      0.09      0.02     14884
#                          weighted avg       0.01      0.10      0.02     14884
#
# Najczęściej mylone klasy: basil → penguin
# Liczba pomyłek: 1430
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/mk/miniconda3/envs/dnn_gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import multiModel as mm
from multiModel import MultiInputModel
from glob import glob
import os
import matplotlib.pyplot as plt
import numpy as np

# Załaduj dane
test_dataset = mm.MultiInputDataset("CSV/dataset/test.csv", transform_rgb=mm.transform_rgb, transform_binary=mm.transform_binary)
test_loader = mm.DataLoader(test_dataset, batch_size=32, shuffle=False)

path_results = "training_results2"
for path_model in glob(f"{path_results}/*.pth"):
    print(f"Testowanie modelu: {path_model}")
    # Wywołanie funkcji testującej
    cm, y_true, y_pred = mm.test_model(
        path_model=path_model,
        test_loader=test_loader,
        device="cuda"
    )

    # Wyświetlenie macierzy pomyłek
    class_names = list(test_dataset.class_to_idx.keys())
    plt.figure(figsize=(10, 8))
    mm.sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Przewidywane klasy")
    plt.ylabel("Rzeczywiste klasy")
    plt.title(f"Macierz pomyłek: {os.path.split(os.path.basename(path_model))[0]}")
    plt.savefig(os.path.splitext(path_model)[0] + ".png", dpi=300, bbox_inches="tight")
    plt.show()

    # Inne metryki


    # Otwórz plik w trybie zapisu
    with open(os.path.splitext(path_model)[0] + ".txt", "w") as file:
        # Zapisz dokładność
        accuracy = mm.accuracy_score(y_true, y_pred)
        file.write(f"Dokładność: {accuracy:.4f}\n")
        
        # Zapisz raport klasyfikacji
        classification_report = mm.classification_report(y_true, y_pred, target_names=class_names)
        file.write("\nRaport klasyfikacji:\n")
        file.write(classification_report + "\n")
        
        # Zapisz informacje o największej liczbie pomyłek
        off_diagonal = cm - np.diag(np.diag(cm))  # Macierz bez przekątnej
        max_misclassified = np.unravel_index(np.argmax(off_diagonal), off_diagonal.shape)
        
        most_confused_classes = f"Najczęściej mylone klasy: {class_names[max_misclassified[0]]} → {class_names[max_misclassified[1]]}"
        misclassified_count = f"Liczba pomyłek: {off_diagonal[max_misclassified]}"
        
        file.write("\n" + most_confused_classes + "\n")
        file.write(misclassified_count + "\n")
        file.close()

    # Wyświetl w konsoli również, jeśli chcesz
    print(f"Dokładność: {accuracy:.4f}")
    print("\nRaport klasyfikacji:")
    print(classification_report)
    print(most_confused_classes)
    print(misclassified_count)
