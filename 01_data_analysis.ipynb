# %% [markdown]
# #### 1. Prepare env

# %%
#pip install numpy pandas matplotlib seaborn opencv-python scikit-learn torch torchvision pytorch-lightning albumentations fastai streamlit

# %% [markdown]
# 1. Załaduj obrazy i zbierz ich wymiary
# Najpierw załaduj obrazy z katalogów i odczytaj ich wymiary przy użyciu Pillow lub OpenCV.

# %%
from pathlib import Path
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt

N = 6 #WAŻNE - iteracja analizy zbioru danych - każda kolejna iteracja analizy zbioru powinna być wyższa od wcześniejszej. 

# Ścieżka do katalogu z danymi
data_dir = Path("/media/512GB_ext/preprocesed_dataset/")

# Zbieranie wymiarów obrazów
image_data = []
for class_dir in data_dir.iterdir():
    if class_dir.is_dir():
        class_name = class_dir.name
        for img_path in class_dir.glob("*.*"):  # Wczytuj wszystkie obrazy
            try:
                with Image.open(img_path) as img:
                    width, height = img.size
                    image_data.append({"class": class_name, "width": width, "height": height, "path": str(img_path)})
            except Exception as e:
                print(f"Błąd wczytywania obrazu: {img_path}, {e}")

# Przechowywanie danych w DataFrame
df = pd.DataFrame(image_data)
print(df.head())
# Out:
#    class  width  height                                               path
# 0  basil    232     630  /media/512GB_ext/preprocesed_dataset/basil/328...
# 1  basil    223     491  /media/512GB_ext/preprocesed_dataset/basil/351...
# 2  basil    220     694  /media/512GB_ext/preprocesed_dataset/basil/373...
# 3  basil    210     505  /media/512GB_ext/preprocesed_dataset/basil/305...
# 4  basil    234     638  /media/512GB_ext/preprocesed_dataset/basil/305...

# %% [markdown]
# 2. Analiza rozkładu wymiarów
# 2.1. Podstawowe statystyki
# Policz podstawowe statystyki wymiarów:

# %%
print(df.describe())
# Out:
#                width         height
# count  301930.000000  301930.000000
# mean      232.262551     561.348392
# std        16.783705      74.928957
# min       150.000000     340.000000
# 25%       221.000000     511.000000
# 50%       232.000000     543.000000
# 75%       243.000000     608.000000
# max       310.000000     884.000000

# %% [markdown]
# 2.2. Wizualizacja rozkładu szerokości i wysokości
# Za pomocą wykresów histogramów lub rozkładów możesz sprawdzić, czy wymiary są zgodne z oczekiwaniami:

# %%
plt.figure(figsize=(12, 6))

# Histogram dla szerokości
plt.subplot(1, 2, 1)
plt.hist(df['width'], bins=50, color='skyblue', edgecolor='black')
plt.title("Rozkład szerokości obrazów")
plt.xlabel("Szerokość (pixele)")
plt.ylabel("Liczba obrazów")

# Histogram dla wysokości
plt.subplot(1, 2, 2)
plt.hist(df['height'], bins=50, color='lightgreen', edgecolor='black')
plt.title("Rozkład wysokości obrazów")
plt.xlabel("Wysokość (pixele)")
plt.ylabel("Liczba obrazów")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2.3. Wizualizacja zależności między szerokością a wysokością
# Przydatny może być scatter plot, który pokaże, jak szerokości i wysokości są rozłożone względem siebie:

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['width'], df['height'], alpha=0.5, c='blue')
plt.title("Rozkład szerokości i wysokości obrazów")
plt.xlabel("Szerokość (pixele)")
plt.ylabel("Wysokość (pixele)")
plt.show()

# %% [markdown]
# 3. Identyfikacja przypadków odstających
# 3.1. Wyznaczenie progów za pomocą IQR (Interquartile Range)
# Możesz wykorzystać metodę IQR do identyfikacji obrazów o nietypowych wymiarach:

# %%
# Oblicz IQR dla szerokości i wysokości
Q1_width = df['width'].quantile(0.25)
Q3_width = df['width'].quantile(0.75)
IQR_width = Q3_width - Q1_width

Q1_height = df['height'].quantile(0.25)
Q3_height = df['height'].quantile(0.75)
IQR_height = Q3_height - Q1_height

# Wyznacz dolne i górne granice
lower_bound_width = Q1_width - 1.5 * IQR_width
upper_bound_width = Q3_width + 1.5 * IQR_width

lower_bound_height = Q1_height - 1.5 * IQR_height
upper_bound_height = Q3_height + 1.5 * IQR_height

# Filtruj przypadki odstające
outliers = df[
    (df['width'] < lower_bound_width) | (df['width'] > upper_bound_width) |
    (df['height'] < lower_bound_height) | (df['height'] > upper_bound_height)
]

print(f"Liczba przypadków odstających: {len(outliers)}")
print(outliers)
# Out:
# Liczba przypadków odstających: 5143
#                 class  width  height  \
# 47              basil    283     622
# 237             basil    284     645
# 254             basil    228     348
# 346             basil    185     520
# 603             basil    278     547
# ...               ...    ...     ...
# 301798  ziarna_zdrowe    278     655
# 301858  ziarna_zdrowe    247     793
# 301861  ziarna_zdrowe    249     756
# 301911  ziarna_zdrowe    245     807
# 301928  ziarna_zdrowe    280     686
#
#                                                      path
# 47      /media/512GB_ext/preprocesed_dataset/basil/305...
# 237     /media/512GB_ext/preprocesed_dataset/basil/306...
# 254     /media/512GB_ext/preprocesed_dataset/basil/306...
# 346     /media/512GB_ext/preprocesed_dataset/basil/306...
# 603     /media/512GB_ext/preprocesed_dataset/basil/307...
# ...                                                   ...
# 301798  /media/512GB_ext/preprocesed_dataset/ziarna_zd...
# 301858  /media/512GB_ext/preprocesed_dataset/ziarna_zd...
# 301861  /media/512GB_ext/preprocesed_dataset/ziarna_zd...
# 301911  /media/512GB_ext/preprocesed_dataset/ziarna_zd...
# 301928  /media/512GB_ext/preprocesed_dataset/ziarna_zd...
#
# [5143 rows x 4 columns]

# %% [markdown]
# 3.2. Wyświetlenie przypadków odstających
# Możesz załadować i wyświetlić przypadki odstające w celu ich analizy:

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Wyświetl kilka przypadków odstających
def show_outliers(outliers_df, n=10):
    fig, axs = plt.subplots(1, n, figsize=(n * 3, 3))
    for i, (_, row) in enumerate(outliers_df.iterrows()):
        if i >= n:
            break
        img = Image.open(row['path'])
        axs[i].imshow(img)
        axs[i].axis('off')
        axs[i].set_title(f"{row['width']}x{row['height']}")
    plt.tight_layout()
    plt.show()

show_outliers(outliers, 20)

# %% [markdown]
# 4. Wizualizacja rozkładu dla poszczególnych klas
# Możesz również sprawdzić, czy wymiary różnią się między klasami:

# %%
import seaborn as sns

# Rozkład szerokości w zależności od klasy
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='class', y='width')
plt.title("Rozkład szerokości obrazów w zależności od klasy")
plt.xticks(rotation=45)
plt.show()

# Rozkład wysokości w zależności od klasy
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='class', y='height')
plt.title("Rozkład wysokości obrazów w zależności od klasy")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Oznacz odstające obrazy: Możesz dodać kolumnę w DataFrame, aby oznaczyć obrazy, które wymagają uwagi:

# %%
df['is_outlier'] = False
df.loc[outliers.index, 'is_outlier'] = True

# %% [markdown]
# Eksportuj listę odstających przypadków: Zapisz szczegóły tych obrazów do pliku CSV:

# %%
outliers.to_csv(f"outliers{N}.csv", index=False)

# %% [markdown]
# 5.1. Eksportuj wyniki analizy do CSV
# Po wykonaniu wszystkich obliczeń i detekcji odstających przypadków, zapisz wyniki do pliku CSV, który ułatwi dalszą pracę:

# %%
df.to_csv(f"dataset_analysis{N}.csv", index=False)

# %% [markdown]
# 5.2. Automatyczne grupowanie outlierów
# Możesz wykorzystać algorytmy takie jak DBSCAN lub Isolation Forest do automatycznego grupowania odstających przypadków:

# %%
from sklearn.ensemble import IsolationForest

# Wyodrębnienie wymiarów
dims = df[['width', 'height']].values

# Model Isolation Forest
iso = IsolationForest(contamination=0.01, random_state=42)
df['outlier_score'] = iso.fit_predict(dims)

# Zapisz wyniki
df['is_outlier'] = df['outlier_score'] == -1
df.to_csv(f"outliers_detected{N}.csv", index=False)

# %%
import pandas as pd

# Wczytaj plik CSV
input_csv = f"outliers_detected{N}.csv"  # Ścieżka do oryginalnego pliku
output_csv = f"outliers_detected_out{N}.csv"  # Ścieżka do pliku wynikowego

# Wczytaj dane
df = pd.read_csv(input_csv)

# Grupowanie obrazów na podstawie wspólnego identyfikatora (przed sufiksem *_T.png, *_B.png, *_S.png)
# Wyciągnij identyfikator obiektu (ścieżka bez końcówki "_T", "_B", "_S")
df['object_id'] = df['path'].str.replace(r'_[TBS]\.png$', '', regex=True)

# Sprawdź, czy dla danego obiektu jakikolwiek widok jest outlierem
outlier_objects = df[df['is_outlier'] == True]['object_id'].unique()

# Ustaw is_outlier = True dla wszystkich widoków tych obiektów
df['is_outlier'] = df['object_id'].isin(outlier_objects)

# Zapisz wynik do nowego pliku CSV
df.drop(columns=['object_id'], inplace=True)  # Usuń dodatkową kolumnę pomocniczą
df.to_csv(output_csv, index=False)

print(f"Zapisano wynik do pliku: {output_csv}")
# Out:
# Zapisano wynik do pliku: outliers_detected_out5.csv

# %%
import os
import shutil
from pathlib import Path
import pandas as pd

def move_outliers(csv_file, destination_root):
    """
    Przenosi pliki z is_outlier=True do nowego katalogu, zachowując strukturę katalogów i nazwy plików.

    Args:
        csv_file (str): Ścieżka do pliku CSV zawierającego informacje o plikach.
        destination_root (str): Ścieżka do głównego katalogu przeznaczonego na outliery.
    """
    # Wczytaj dane z CSV
    df = pd.read_csv(csv_file)

    # Filtruj pliki z is_outlier=True
    outlier_files = df[df['is_outlier'] == True]['path']

    # Iteruj przez każdy plik oznaczony jako outlier
    for file_path in outlier_files:
        # Utwórz docelową ścieżkę (zastępujemy "preprocesed_dataset" na "preprocesed_dataset_outliers")
        source_path = Path(file_path)
        relative_path = source_path.relative_to(source_path.parents[1])  # Zachowaj strukturę katalogów
        destination_path = Path(destination_root) / relative_path

        # Utwórz katalog docelowy, jeśli nie istnieje
        destination_path.parent.mkdir(parents=True, exist_ok=True)

        # Przenieś plik
        try:
            shutil.move(str(source_path), str(destination_path))

            print(f"Przeniesiono plik: {source_path} -> {destination_path}")
        except:
            print(f"Plik nie istnieje: {source_path}")

# Przykład użycia:
csv_file = f"outliers_detected_out{N}.csv"  # Plik CSV z analizą
destination_root = f"/media/512GB_ext/preprocesed_dataset_outliers{N}"  # Docelowy katalog dla outlierów

move_outliers(csv_file, destination_root)
# Out:
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30622_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30622_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30622_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30622_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30622_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30622_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30736_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30736_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30736_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30736_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30736_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30736_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30787_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30787_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30787_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30787_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30787_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30787_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30910_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30910_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30910_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30910_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30910_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30910_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30951_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30951_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30951_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30951_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30951_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30951_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30962_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30962_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30962_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30962_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/30962_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/30962_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31004_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31004_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31004_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31004_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31004_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31004_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31078_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31078_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31078_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31078_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31078_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31078_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31831_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31831_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31957_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31957_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31319_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31319_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31319_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31319_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31319_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31319_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31433_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31433_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31433_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31433_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31433_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31433_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31466_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31466_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31466_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31466_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31466_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31466_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31611_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31611_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31611_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31611_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31611_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31611_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31659_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31659_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31659_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31659_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31659_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31659_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31686_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31686_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31686_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31686_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31686_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31686_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31722_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31722_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31722_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31722_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31722_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31722_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31798_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31798_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31798_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31798_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31798_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31798_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31831_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31831_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31831_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31831_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31923_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31923_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31923_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31923_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31923_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31923_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31944_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31944_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31944_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31944_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31944_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31944_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31957_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31957_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/31957_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/31957_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32087_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32087_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32087_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32087_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32087_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32087_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32171_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32171_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32171_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32171_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32171_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32171_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32195_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32195_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32195_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32195_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32196_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32196_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32196_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32196_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32196_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32196_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32195_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32195_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32238_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32238_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32238_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32238_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32301_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32301_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32301_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32301_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32301_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32301_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32238_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32238_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32346_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32346_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32346_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32346_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32346_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32346_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32404_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32404_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32404_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32404_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32450_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32450_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32450_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32450_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32450_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32450_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32404_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32404_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32546_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32546_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32546_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32546_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32546_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32546_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32667_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32667_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32667_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32667_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32667_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32667_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32717_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32717_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32717_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32717_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32717_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32717_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32720_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32720_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32720_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32720_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32720_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32720_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32916_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32916_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32916_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32916_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32916_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32916_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32941_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32941_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32941_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32941_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32941_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32941_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32997_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32997_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32997_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32997_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/32997_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/32997_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33191_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33191_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33191_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33191_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33191_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33191_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33198_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33198_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33198_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33198_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33198_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33198_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33278_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33278_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33278_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33278_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33280_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33280_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33280_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33280_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33280_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33280_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33278_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33278_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33434_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33434_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33434_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33434_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33434_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33434_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33487_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33487_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33487_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33487_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33487_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33487_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33817_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33817_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33817_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33817_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33817_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33817_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33867_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33867_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33867_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33867_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33867_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33867_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33879_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33879_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33879_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33879_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/33879_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/33879_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34016_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34016_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34016_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34016_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34016_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34016_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34091_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34091_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34091_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34091_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34091_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34091_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34243_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34243_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34243_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34243_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34243_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34243_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34249_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34249_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34249_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34249_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34249_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34249_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34351_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34351_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34351_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34351_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34351_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34351_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34498_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34498_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34498_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34498_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34498_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34498_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34501_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34501_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34501_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34501_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34501_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34501_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34529_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34529_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34529_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34529_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34529_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34529_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34643_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34643_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34643_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34643_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34648_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34648_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34648_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34648_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34648_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34648_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34657_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34657_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34657_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34657_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34697_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34697_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34697_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34697_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34697_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34697_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34643_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34643_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34657_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34657_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34764_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34764_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34764_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34764_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34764_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34764_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34886_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34886_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34886_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34886_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34886_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34886_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34974_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34974_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34974_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34974_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/34974_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/34974_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35008_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35008_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35008_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35008_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35008_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35008_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35029_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35029_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35029_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35029_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35029_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35029_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35065_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35065_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35065_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35065_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35065_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35065_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35163_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35163_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35163_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35163_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35163_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35163_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35186_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35186_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35186_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35186_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35186_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35186_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35205_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35205_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35205_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35205_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35205_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35205_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35263_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35263_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35263_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35263_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35263_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35263_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35564_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35564_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35564_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35564_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35564_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35564_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35793_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35793_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35793_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35793_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35793_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35793_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35830_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35830_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35830_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35830_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35830_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35830_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35836_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35836_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35836_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35836_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35836_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35836_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35866_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35866_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35866_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35866_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35866_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35866_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35922_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35922_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35922_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35922_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35922_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35922_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35933_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35933_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35933_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35933_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/35933_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/35933_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36085_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36085_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36085_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36085_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36085_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36085_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36136_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36136_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36136_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36136_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36136_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36136_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36172_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36172_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36172_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36172_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36172_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36172_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36176_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36176_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36176_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36176_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36176_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36176_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36192_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36192_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36192_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36192_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36192_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36192_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36346_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36346_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36346_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36346_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36346_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36346_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36376_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36376_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36376_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36376_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36376_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36376_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36496_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36496_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36496_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36496_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36496_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36496_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36519_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36519_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36519_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36519_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36519_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36519_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36720_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36720_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36720_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36720_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36720_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36720_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36815_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36815_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36815_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36815_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36815_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36815_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36910_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36910_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36910_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36910_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36930_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36930_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36930_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36930_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36930_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36930_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36933_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36933_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36933_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36933_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36933_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36933_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36993_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36993_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36993_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36993_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36993_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36993_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/36910_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/36910_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37056_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37056_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37056_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37056_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37056_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37056_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37131_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37131_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37131_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37131_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37131_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37131_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37263_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37263_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37263_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37263_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37263_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37263_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37498_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37498_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37498_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37498_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37498_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37498_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37515_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37515_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37515_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37515_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37515_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37515_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37516_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37516_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37516_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37516_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37516_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37516_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37550_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37550_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37550_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37550_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37550_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37550_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37601_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37601_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37601_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37601_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37601_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37601_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37663_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37663_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37663_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37663_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37663_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37663_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37664_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37664_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37664_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37664_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37664_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37664_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37846_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37846_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37846_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37846_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37846_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37846_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37918_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37918_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37918_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37918_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37918_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37918_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37966_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37966_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37966_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37966_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37966_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37966_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37997_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37997_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37997_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37997_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/37997_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/37997_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38147_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38147_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38147_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38147_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38147_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38147_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38206_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38206_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38206_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38206_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38206_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38206_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38209_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38209_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38209_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38209_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38209_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38209_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38313_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38313_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38313_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38313_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38313_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38313_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38424_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38424_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38424_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38424_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38424_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38424_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38488_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38488_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38488_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38488_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38514_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38514_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38514_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38514_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38514_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38514_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38488_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38488_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38601_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38601_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38601_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38601_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38601_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38601_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38710_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38710_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38710_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38710_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38710_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38710_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38756_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38756_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/basil/38756_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/basil/38756_S.png
# ...
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00160_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00160_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00160_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00160_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00163_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00163_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00163_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00163_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00163_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00163_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00171_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00171_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00171_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00171_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00171_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00171_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00184_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00184_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00184_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00184_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00184_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00184_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00245_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00245_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00245_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00245_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00245_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00245_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00432_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00432_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00432_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00432_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00432_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00432_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00440_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00440_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00440_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00440_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00440_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00440_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00457_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00457_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00457_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00457_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00457_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00457_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00459_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00459_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00459_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00459_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00459_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00459_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00531_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00531_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00531_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00531_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00531_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00531_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00556_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00556_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00556_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00556_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00591_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00591_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00591_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00591_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00612_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00612_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00612_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00612_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00624_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00624_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00624_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00624_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00624_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00624_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00556_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00556_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00591_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00591_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00612_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00612_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00686_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00686_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00686_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00686_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00686_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00686_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00791_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00791_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00791_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00791_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00791_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00791_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00882_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00882_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00882_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00882_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00882_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00882_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00937_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00937_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00937_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00937_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00937_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00937_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00988_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00988_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00988_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00988_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00988_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00988_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00990_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00990_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00990_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00990_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/00990_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/00990_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01039_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01039_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01039_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01039_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01039_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01039_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01043_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01043_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01043_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01043_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01043_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01043_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01079_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01079_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01079_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01079_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01079_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01079_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01122_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01122_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01122_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01122_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01122_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01122_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01237_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01237_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01237_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01237_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01265_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01265_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01265_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01265_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01237_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01237_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01265_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01265_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01392_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01392_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01392_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01392_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01392_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01392_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01404_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01404_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01404_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01404_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01404_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01404_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01459_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01459_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01459_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01459_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01459_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01459_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01480_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01480_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01480_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01480_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01480_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01480_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01503_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01503_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01503_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01503_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01503_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01503_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01629_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01629_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01629_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01629_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01629_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01629_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01808_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01808_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01808_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01808_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01808_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01808_T.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01823_B.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01823_B.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01823_S.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01823_S.png
# Przeniesiono plik: /media/512GB_ext/preprocesed_dataset/ziarna_zdrowe/01823_T.png -> /media/512GB_ext/preprocesed_dataset_outliers4/ziarna_zdrowe/01823_T.png

# %% [markdown]
# # *******************************
